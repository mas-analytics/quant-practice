# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# データ取得（Apple）
df = yf.download("AAPL", start="2020-01-01", end="2024-01-01")

# 最初の5行表示
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.333878  72.394086  71.091184  71.344054  135480400
# 2020-01-03  71.630646  72.389265  71.406674  71.563213  146322800
# 2020-01-06  72.201408  72.239942  70.503546  70.754014  118387200
# 2020-01-07  71.861839  72.466322  71.642681  72.211041  108872000
# 2020-01-08  73.017845  73.318885  71.565629  71.565629  132079200

# %%
df["Close"].plot(title="AAPL Price")
plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# データ取得（Apple）
df = yf.download("NVDA", start="2020-01-01", end="2024-01-01")

# 最初の5行表示
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          NVDA      NVDA      NVDA      NVDA       NVDA
# Date
# 2020-01-02  5.970754  5.970754  5.891364  5.941885  237536000
# 2020-01-03  5.875187  5.918990  5.826159  5.851047  205384000
# 2020-01-06  5.899824  5.905050  5.755726  5.781857  262636000
# 2020-01-07  5.971251  6.017044  5.883149  5.928196  314856000
# 2020-01-08  5.982450  6.023764  5.926952  5.967020  277108000

# %%
df["Close"].plot(title="NVDAPrice")
plt.show()

# %%
# リターン計算（対数リターン）
import numpy as np

df["Return"] = np.log(df["Close"] / df["Close"].shift(1))

df[["Close", "Return"]].head()
# Out:
# Price          Close    Return
# Ticker          NVDA
# Date
# 2020-01-02  5.970754       NaN
# 2020-01-03  5.875187 -0.016135
# 2020-01-06  5.899824  0.004185
# 2020-01-07  5.971251  0.012034
# 2020-01-08  5.982450  0.001874

# %%
df["Return"].plot(title="AAPL Log Returns")
plt.show()

# %%
df["Return"].hist(bins=50)
plt.title("Return Distribution")
plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# データ取得（Apple）
df = yf.download("^N225", start="2020-01-01", end="2024-01-01")

# 最初の5行表示
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open    Volume
# Ticker             ^N225         ^N225         ^N225         ^N225     ^N225
# Date
# 2020-01-06  23204.859375  23365.359375  23148.529297  23319.759766  72800000
# 2020-01-07  23575.720703  23577.439453  23299.919922  23320.119141  64300000
# 2020-01-08  23204.759766  23303.210938  22951.179688  23217.490234  79400000
# 2020-01-09  23739.869141  23767.089844  23506.150391  23530.289062  62200000
# 2020-01-10  23850.570312  23903.289062  23761.080078  23813.279297  55900000

# %%
df["Close"].plot(title="^N225 Price")
plt.show()

# %%
# リターン計算（対数リターン）
import numpy as np

df["Return"] = np.log(df["Close"] / df["Close"].shift(1))

df[["Close", "Return"]].head()
# Out:
# Price              Close    Return
# Ticker             ^N225
# Date
# 2020-01-06  23204.859375       NaN
# 2020-01-07  23575.720703  0.015856
# 2020-01-08  23204.759766 -0.015860
# 2020-01-09  23739.869141  0.022798
# 2020-01-10  23850.570312  0.004652

# %%
df["Return"].plot(title="^N225 Log Returns")
plt.show()

# %%
df["Return"].hist(bins=50)
plt.title("Return Distribution")
plt.show()

# %%
# CSV保存
df.to_csv("AAPL_data.csv")

# %%
df.to_csv("data/AAPL_data.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df.to_csv("data/AAPL_data.csv")
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3984             float_format=float_format,
#    3985             decimal=decimal,
#    3986         )
#    3987
# -> 3988         return DataFrameRenderer(formatter).to_csv(
#    3989             path_or_buf,
#    3990             lineterminator=lineterminator,
#    3991             sep=sep,
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\formats\format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
#     272     self._save()
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\common.py:793, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     791 # Only for write methods
#     792 if "r" not in mode and is_path:
# --> 793     check_parent_directory(str(handle))
#     795 if compression:
#     796     if compression != "zstd":
#     797         # compression libraries do not like an explicit text-mode
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\common.py:652, in check_parent_directory(path)
#     650 parent = Path(path).parent
#     651 if not parent.is_dir():
# --> 652     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data'

# %%
# CSV保存
df.to_csv("NVDA_data.csv")

# %%
df.to_csv("data/^N225_data.csv")

# %%
print("Hello")

# %%
close.head()

# %%
Close.head()

# %%
close=df["Close"]["AAPL"]

# %%
import yfinance as yf

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = download("AAPL",start="2020-01-01")

# %%
df = yf.download("AAPL",start="2020-01-01")

# %%
df.head()

# %%
close=df["Close"]["AAPL"]

# %%
close.head()

# %% [markdown]
# ma50=close.rolling(50).mean()

# %%
ma50=close.rolling(50).mean()

# %%
signal=close>ma50

# %%
returns=close.pct_change()

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
cumulative_returns.iloc[-1]

# %%
rolling_max=cumulative_returnscummax()

# %%
rolling_max=cumulative_returns.cummax()

# %%
rolling_mas.tail()

# %%
rolling_max.tail()

# %%
drawdown=(cumulative_returns-rolling_max)/rolling_max

# %%
drawdown.tail()

# %%
max_drawdown=drawdown.min()

# %%
max_drawdown

# %%
buy_hold=(1+returns).cumprod()

# %%
buy_hold.iloc[-1]

# %%
buy_hold_max=buy_hold.cumax()

# %%
buy_hold_max=buy_hold.cummax()

# %%
buy_hold_drawdown=(buy_hold-buy_hold_max)/buy_hold_max

# %%
buy_hold_max_drawdown=buy_hold_drawdown.min()

# %%
buy_hold_max_drawdown

# %%
buy_hold.plot(figsize=(12,5),label="Buy & Hold")

# %%
cumulative_returns.plot(label="MA50 Strategy")

# %%
 plt.legend()

# %%
pld.figure(figsiz=(12,5))

# %%
plt.figure(figsize=(12,5))

# %%
plt.plot(buy_hold,label="Buy & Hold")

# %%
plt.plot(cumulative_returns,label="MA50 Strategy")

# %%
plt.legend()

# %%
type(buy_hold)

# %%
type(cumulative_returns)

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA50 Strategy")
plt.legend()

# %%
plt.show()

# %%
ticker="NVDA"

# %%
df=yf.download(ticker)

# %%
close=df["Close"][ticker]

# %%
plt.title(ticker)

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA50 Strategy")
plt.title(ticker)
plt.legend()
plt.show()

# %%
cumulative_returns.iloc[-1]

# %%
buy_hold_max_drawdown

# %%
max_drawdown

# %%
buy_hold.iloc[-1]

# %%
buy_hold_max_drawdown

# %%
df=yf.download(ticker)

# %%
close=df["Close"][ticker]

# %%
ma50=close.rolling(50).mean()

# %%
signal=close>ma50

# %%
returns=close.pct_change()

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
buy_hold=(1+returns).cumprod()

# %%
cumlative_returns.iloc[-1]

# %%
cumulative_returns.iloc[-1]

# %%
buy_hold.iloc[-1]

# %%
df.tail()

# %%
signal.value_counts()

# %%
df=yf.download(ticker,period="5y")

# %%
period="5y"

# %%
df=yf.download(ticker,period="5y")

# %%
df.head()

# %%
close=df["Close"][ticker]

# %%
close.head()

# %%
ma50=close.rolling(50).mean()

# %%
ma50.head(60)

# %%
signal=close>ma50

# %%
signal.tail()

# %%
returns=close.pct_change()

# %%
returns.tail()

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int).returns

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
cumulative_returns.tail()

# %%
buy_hold=(1+returns).cumprod()

# %%
buy_hold.tail()

# %%
plt.figure(figsaize=(12,5))

# %%
pld.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA50 strategy")
plt.title(ticker)
plt.legend()
plot.show()

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA50 strategy")
plt.title(ticker)
plt.legend()
plot.show()

# %%
rolling_max=cumulative_returns.cummax()

# %%
rolling_max.tail()

# %%
drawdown=cumulative_returns/rolling_max-1

# %%
max_drawdown=drawdown.min()

# %%
max_drawdown

# %%
buy_hold_rolling_max=buy_hold.cummax()

# %%
buy_hold_drawdown=buy_hold/buy_hold_rolling_max-1

# %%
buy_hold_max_drawdow=buy_hold_drawdown.min()

# %%
buy_hold_max_drawdown=buy_hold_drawdown.min()

# %%
buy_hold_max_drawdown

# %%
strategy_returns.mean()

# %%
strategy_returns.std()

# %%
sharpe.ratio=strategy_returns.mean()/strategy_returns.std()

# %%
sharpe_ratio=strategy_returns.mean()/strategy_returns.std()

# %%
sharpe_ratio

# %%
annual_sharpe=sharpe_ratio*np.sqrt(252)

# %%
import numpy as np

# %%
annual_sharpe=sharpe_ratio*np.sqrt(252)

# %%
annual_sharpe

# %%
returns.mean()

# %%
returns.std()

# %%
buy_hold_sharpe=returns.mean()/returns.std()

# %%
buy_hold_annual_sharpe=buy_hold_sharpe*np.sqrt(252)

# %%
buy_hold_annual_sharpe

# %%
np.float64(1.3010779455839798)

# %%
ticker="RKLB"

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import yfinance as yf

# %%
df=yf.download(ticker,period="5y")

# %%
close=df["Close"][ticker]

# %%
ma50=close.rolling(50).mean()

# %%
signal=close>ma50

# %%
returns=close.pct_change()

# %%
strategy_returns=sgnal.shift(1).fillna(False).astype(int)*returns

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_rerurn=(1+strategy_returns).cumprod()

# %%
buy_hold=(1+returns).cumprod()

# %%
plt.figure(figsize=(12,5))

# %%
plt.figure(figsize=(12,5))

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA50 Strategy")
plt.title(ticker)
plt.legend()
plt.show()

# %%
rolling_max=cumulative_returns.cummax()

# %%
drawdown=cumulative_returns/rolling_max-1

# %%
max_drawdow=drawdown.min()

# %%
buy_hold_rolling_max=buy_hold.cummax

# %%
buy_hold_rolling_max=buy_hold.cummax()

# %%
buy_hold_drawdown=buy_hold/buy_hold_rolling_max-1

# %%
buy_hold_max_drawdown=buy_hold_drawdown.min()

# %%
sharpe_ratio=strategy_returns.mean()/returns.std()

# %%
annual_sharpe=sharpe_ratio*np.sqrt(252)

# %%
buy_hold_sharpe=returns.mean()/returns.std()

# %%
buy_hold_annual_sharpe=buy_hold_sharpe*np.sqrt(252)

# %%
cummulative_returns.iloc[-1]

# %%
cumulative_returns.iloc[-1]

# %%
buy_hold.iloc[-1]

# %%
max_drawdown

# %%
buy_hold_max_drawdown

# %%
annual_sharpe

# %%
buy_hold_annual_sharpte

# %%
buy_hold_annual_sharpe

# %%
ma200=close.rolling(200).mean()

# %%
signal=close>ma200

# %%
returns=close.pct_change()

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA200 Strategy")
plt.title(ticker)
plt.legend()
plt.show()

# %%
rolling_max=cumulative_returns.cummax()

# %%
drawdown=cumlative_returns/rolling_max-1

# %%
drawdown=cumulative_returns/rolling_max-1

# %%
max_drawdown=drawdown.min()

# %%
sharpe_ratio=strategy_returns.mean()/strategy_returns.std()

# %%
annual_sharpe=sharpe_ratio*np.sqrt(252)

# %%
cumurative_returns.iloc[-1]

# %%
cumulative_returns.iloc[-1]

# %%
max_drawdown

# %%
annual_shape

# %%
annual_sharpe

# %%
signal.value_counts()

# %%
cumulative_returns.iloc[-1]

# %%
buy_hold.iloc[-1]

# %%
ma100=close.rolling(100).mean()

# %%
signal=close>ma100

# %%
returns=close.pct_change()

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(strategy_returns,label="MA100 Strategy")
plt.title(ticker)
plt.legend()
plt.show()

# %%
signal.value_counts()

# %%
close.head()

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA100 Strategy")
plt.title(ticker)
plt.legend()
plt.show()

# %%
rolling_max=cumulative_returns.cummax()

# %%
drawdown=cumulative_returns/rolling_max-1

# %%
max_drawdown=drawdown.min()

# %%
sharpe_ratio=strategy_retunrns.mean()/strategy_returns.std()

# %%
sharpe_ratio=strategy_returns.mean()/strategy_returns.std()

# %%
annual_sharpe=sharpe_ratio*np.sqrt(252)

# %%
cumulative_returns.iloc[-1]

# %%
max_drawdown

# %%
annual_sharpe

# %%
ticker="AAPL"

# %%
df=yf.download(ticker,period="5y")

# %%
close=df[Close

# %%
close=df

# %%
close=de["Close"][ticker]

# %%
close=df["Close"][ticker]

# %%
close.hed()

# %%
closel.head()

# %%
close.head()

# %%
ma200=close.rolling(200).mean()

# %%
signal=close>ma200

# %%
returns=close.pct_change()

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_returns=(1+strategy_returns)*cumprod()

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
buy_hold=(1+close).cumuprod()

# %%
buy_hold=(1+returns).cumrod()

# %%
buy_hold=(1+returns)/cumprod()

# %%
buy_hold=(1+returns).cumuprod()

# %%
buy_hold=(1+returns).cumprod()

# %%
import pandas as pd

# %%
import nupy as np

# %%
import numpy as np

# %%
import as yfinance as yf

# %%
import yfinance as yf

# %%
import matplotlib as plt

# %%
ticker = "AAPLE"

# %%
df=yf.download(ticker,start="2015-01-01")

# %%
ticker="AAPL"

# %%
d=yf.download(ticker,start="2015-01-01")

# %%
df.head()

# %%
df=yf.download(ticker,perio="5y")

# %%
d=yf.download(ticker,period="5y")

# %%
close=df["Close"][ticker]

# %%
df.columns

# %%
ticker="APPL"

# %%
df=yf.download(ticker,period="5y")

# %%
ticker="AAPL"

# %%
df=yf.download(ticker,period="5y")

# %%
close=df["Close"][ticker]

# %%
ma200=close.rolling(200).mean()

# %%
signal=close>ma200

# %%
returns=close.pct_change()

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_returns=(1+strategy_returns).cumuprod()

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
buy_hold=(1+returns).cumprod()

# %%
plt.figure(figsize=(12,5))

# %%
pld.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA200 Strategy")
plt.title(ticker)
plt.legend()
plt.show

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA200 Strategy")
plt.title(ticker)
plt.legend()
plt.show

# %%
type(plt)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,5))
plt.plot(buy_hold,label="Buy & Hold")
plt.plot(cumulative_returns,label="MA200 Strategy")
plt.title(ticker)
plt.legend()
plt.show

# %%
rolling_max=cumulative_returns.cummax()

# %%
drowdown=cumulative_returns/rolling_max-1

# %%
drawdown=cumulative_returns/rollingmax-1

# %%
drawdown=cumulative_returns/rolling_max-1

# %%
max_drawdown=drawdown.min()

# %%
buy_hold_rolling_max=buy_hold.cummax()

# %%
buy_hold_drawdown=buy_hold/buy_hold_rolling_max-1

# %%
buy_hold_max_drawdown=buy_hold_drawdown.min()

# %%
sharpe_ratio=strategy_returns.mean()/strategy_returns.std

# %%
sharpe_ratio=strategy_returns.mean()/strategy_returns.std()

# %%
annual_sharpe=sharpe_ratio:np.sqrt(252)

# %%
annual_sharpe=sharpe_ratio*np.sqrt(252)

# %%
buy_hold_sharpe=returns.mean()/returns.std()

# %%
buy_hold_annual_sharpe=buy_hold_sharpe*np.sqrt(252)

# %%
cumulative_returns.iloc[-1]

# %%
buy_hold.iloc[-1]

# %%
max_drawdown

# %%
buy_hold_max_drawdown

# %%
annual_sharpe

# %%
 buy_hold_annual_sharpe

# %%
ticker="RKLB"

# %%
import yfinance as yf

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
import numpy as np

# %%
df=yf.download(ticker,period="5y")

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
ticker="RKLB"

# %%
df=yf.download(ticker,period="5")

# %%
df=yf.download(ticker,period="5y")

# %%
df.head()

# %%
close=df[Close][ticker]

# %%
close=df["Close"][ticker]

# %%
close.head()

# %%
return=close.pct_change()

# %%
returns=close.pct_change()

# %%
returns.head()

# %%
ma(20)=returns.rolling(20).mean()

# %%
ma(20)=close.rollong(20).mean()

# %%
ma20=close.rolling(20).mena()

# %%
ma20=close.rolling(20).mean()

# %%
ma20.head()

# %%
signal=ma20>close

# %%
strategy_returns=returns.shift(1).fillna(False).astype(int)*returns

# %%
strategy_returns.head()

# %%
ma20.tail()

# %%
signal.head()

# %%
signal.tail()

# %%
strategy_returns=signals.shift(1).fillna(False).astype(int)*returns

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
strategy_returns.tail()

# %%
cumulative_strategy_returns=(1+stratetgy_returns).cumprod()

# %%
cumulative_strategy_returns=(1+strategy_returns).cumprod()

# %%
cumulative_strategy_returns.tail()

# %%
cumulative_returns=(1+returns).cumprod()

# %%
cumulative_returns.tail()

# %%
cumulative_returns=(1+strategy_returns).cumprod

# %%
buy_hold=(1+returns).cumprod()

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
plt.figure(figsize=(12,5))

# %%
plt.figure(figsize=(12,5))
plt.plot(cumulative_returns,label="MA20")
plt.plot(buy_hold,label="Buy & Hold")
plt.title(ticker)
plt.legend()
plt.show

# %%
rolling_max=cumulative_returns.cummax()

# %%
buy_hold_rolling_max=buy_hold.cummax()

# %%
drawdown=cumulative_returns/rolling_max-1

# %%
max_drawdown=drawdown.min()

# %%
buy_hold_drawdown=buy_hold/buy_hold_rolling_max-1

# %%
buy_hold_max_drawdown=buy_hold_drawdown.min()

# %%
sharpe_ratio=strategy_returns.mean()/strategy_returns.std()

# %%
annual_sharpe=sharpe_ratio*np.sqrt(252)

# %%
buy_hold_sharpe_ratio=returns.mean()/returns.std()

# %%
buy_hold_annual_sharpe=buy_hold_sharpe_ratio*np.sqrt(252)

# %%
cumulative_returns.iloc[-1]

# %%
buy_hold_iloc[-1]

# %%
buy_hold.iloc[-1]

# %%
max_drawdown

# %%
buy_hold_max_drawdown

# %%
annual_sharpe

# %%
buy_hold_annual_sharpe

# %%
def backtest_ma(ticker,window):

# %%
def backtest_ma(ticker,window):
    print(ticker)
    print(window)

# %%
backtest_ma("RKLB",20)

# %%
def backtest_ma(ticker,window):

# %%
def backtest_ma(ticker,window):
    print(ticker)
    print(window)

# %%
backtest_ma("RKLB",20)

# %%
backtest_ma

# %%
def backtest_ma(ticker, window):
    print(ticker)
    print(window)

# %%
backtest_ma

# %%
def backtest_ma(ticker, window):
    return ticker, window

# %%
print(backtest_ma)

# %%
print("hello")

# %%
print("hello")

# %%
def backtest_ma(ticker,window):
    de=yf.download(ticker,period="5y")
    close=de["Close"][ticker]
    ma=close.rolling(wondow).mena()
    return ma

# %%
def backtest_ma(ticker,window):
    de=yf.download(ticker,period="5y")
    close=df["Close"][ticker]
    ma=close.rolling(wondow).mena()
    return ma

# %%
ef backtest_ma(ticker,window):
    df=yf.download(ticker,period="5y")
    close=df["Close"][ticker]
    ma=close.rolling(wondow).mena()
    return ma

# %%
def backtest_ma(ticker,window):
    df=yf.download(ticker,period="5y")
    close=df["Close"][ticker]
    ma=close.rolling(wondow).mena()
    return ma

# %%
def backtest_ma(ticker,window):
    df=yf.download(ticker,period="5y")
    close=df["Close"][ticker]
    ma=close.rolling(wondow).mean()
    return ma

# %%
backtest_ma("RKLB",20)

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
def backtest_ma(ticker,window):
    df=yf.download(ticker,period="5y")
    close=df["Close"][ticker]
    ma=close.rolling(wondow).mean()
    return ma

# %%
backtest_ma("RKLB",20)

# %%
def backtest_ma(ticker,window):
    df=yf.download(ticker,period="5y")
    close=df["Close"][ticker]
    ma=close.rolling(window).mean()
    return ma

# %%
backtest_ma("RKLB",20)

# %%
def backtest_ma(ticker, window):

    df = yf.download(ticker, period="5y")

    close = df["Close"][ticker]

    returns = close.pct_change()

    ma = close.rolling(window).mean()

    signal = close > ma

    strategy_returns = (
        signal.shift(1)
        .fillna(False)
        .astype(int)
        * returns
    )

    cumulative_returns = (
        1 + strategy_returns
    ).cumprod()

    return cumulative_returns

# %%
result = backtest_ma("RKLB", 20)

# %%
result.iloc[-1]

# %%
def backtest_ma(ticker, window):

    df = yf.download(ticker, period="5y")

    close = df["Close"][ticker]

    returns = close.pct_change()

    ma = close.rolling(window).mean()

    signal = close > ma

    strategy_returns = (
        signal.shift(1)
        .fillna(False)
        .astype(int)
        * returns
    )

    cumulative_returns = (
        1 + strategy_returns
    ).cumprod()

    rolling_max = cumulative_returns.cummax()

    drawdown = (
        cumulative_returns
        / rolling_max
        - 1
    )

    max_drawdown = drawdown.min()

    annual_sharpe = (
        strategy_returns.mean()
        / strategy_returns.std()
        * np.sqrt(252)
    )

    final_return = cumulative_returns.iloc[-1]

    return (
        final_return,
        max_drawdown,
        annual_sharpe
    )

# %%
result=backtest_ma("RKB",20)

# %%
result=backtest_ma("RKLB",20)

# %%
print(result)

# %%
a,b,c=backtest_ma("RKLB",20)

# %%
a

# %%
b

# %%
c

# %%
a,_,c=backtest_ma("RKLB",20)

# %%
_

# %%
rklb_20 = backtest_ma("RKLB",20)

rklb_50 = backtest_ma("RKLB",50)

rklb_100 = backtest_ma("RKLB",100)

rklb_200 = backtest_ma("RKLB",200)

print(rklb_20)
print(rklb_50)
print(rklb_100)
print(rklb_200)

# %%
windows = [20,50,100,200]
for window in windows:
    result=backtest_ma("RKLB",window)
    print(window,result)

# %%
windows=[20,50,100,200]
results=[]
for window in windows:
    result=backtest_ma("RKLB",window)
    results.append(result)
    print(results)

# %%
print(float(results))

# %%
import yfinance as yf

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
result=backtest_ma("RKLB",20)
print(type(result))
print(result)

# %%
windows=[20,50,100,200]
results=[]
for window in windows
final_return,max_dd,sharpe=backtest_ma("RKLB",window)
results.append(window,final_return,max_dd,_sharpe))

# %%
windows=[20,50,100,200]
results=[]
for window in windows
final_return,max_dd,sharpe=backtest_ma("RKLB",window)
results.append(window,final_return,max_dd,_sharpe)

# %%
windows=[20,50,100,200]
results=[]
for window in windows
final_return,max_dd,sharpe=backtest_ma("RKLB",window):
results.append(window,final_return,max_dd,_sharpe)

# %%
windows=[20,50,100,200]
results=[]
for window in windows:
final_return,max_dd,sharpe=backtest_ma("RKLB",window)
results.append(window,final_return,max_dd,_sharpe)

# %%
windows=[20,50,100,200]
results=[]
for window in windows:
    final_return,max_dd,sharpe=backtest_ma("RKLB",window)
    results.append(window,final_return,max_dd,_sharpe)

# %%
windows=[20,50,100,200]
results=[]
for window in windows:
    final_return,max_dd,sharpe=backtest_ma("RKLB",window)
    results.append(window,final_return,max_dd,sharpe)

# %%
windows=[20,50,100,200]
results=[]
for window in windows:
    final_return,max_dd,sharpe=backtest_ma("RKLB",window)
    results.append((window,final_return,max_dd,sharpe))

# %%
print(results)

# %%
results_df=pd.DataFrame(results,colomns=["window","Return","MaxDD","Sharpe"])

# %%
results_df=pd.DataFrame(results,columns=["window","Return","MaxDD","Sharpe"])

# %%
results_df

# %%
results_fd.sort_values("Sharpe",ascending==False)

# %%
results_df.sort_values("Sharpe",ascending==False)

# %%
results_df.sort_values("Sharpe",ascending=False)

# %%
for x in range(10,31,10)
print(x)

# %%
for x in range(10,31,10):
    print(x)

# %%
results=[]
for window in range(10,301,10):
    final_return,max_dd,sharpe=backtest_ma("RKLB",window)
    results.append((window,final_return,max_dd,sharpe))

# %%
results_df=pd.DataFrame(results,columns=["Window","Return","MaxDD","Sharpe"])

# %%
results_df.sort_values("Sharpe",ascending=False)

# %%
result_df.sort_values("Return",ascending=Flase).head()

# %%
results_df.sort_values("Return",ascending=Flase).head()

# %%
results_df.sort_values("Return",ascending=False).head()

# %%
results_df.sort_values("Return",ascending=False).head(10)

# %%
results_df.sort_values("Sharpe",ascending=Flase).head(10)

# %%
results_df.sort_values("Sharpe",ascending=False).head(10)

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np

# %%
for window in range(10,301,10):
    final_return,max_dd,sharpe=backtest_ma("AAPL",window)
    results.append((window,final_return,max_dd,sharpe))

# %%
for window in range(10,301,10):
    final_return,max_dd,sharpe=backtest_ma("AAPL",window)
    results.append((window,final_return,max_dd,sharpe))

# %%
def backtest_ma(ticker, window):

    df = yf.download(ticker, period="5y")

    close = df["Close"][ticker]

    returns = close.pct_change()

    ma = close.rolling(window).mean()

    signal = close > ma

    strategy_returns = (
        signal.shift(1)
        .fillna(False)
        .astype(int)
        * returns
    )

    cumulative_returns = (
        1 + strategy_returns
    ).cumprod()

    return cumulative_returns

# %%
for window in range(10,301,10):
    final_return,max_dd,sharpe=backtest_ma("AAPL",window)
    results.append((window,final_return,max_dd,sharpe))

# %%
def backtest_ma(ticker, window):

    df = yf.download(ticker, period="5y")

    close = df["Close"][ticker]

    returns = close.pct_change()

    ma = close.rolling(window).mean()

    signal = close > ma

    strategy_returns = (
        signal.shift(1)
        .fillna(False)
        .astype(int)
        * returns
    )

    cumulative_returns = (
        1 + strategy_returns
    ).cumprod()

    rolling_max = cumulative_returns.cummax()

    drawdown = (
        cumulative_returns
        / rolling_max
        - 1
    )

    max_drawdown = drawdown.min()

    annual_sharpe = (
        strategy_returns.mean()
        / strategy_returns.std()
        * np.sqrt(252)
    )

    final_return = cumulative_returns.iloc[-1]

    return (
        final_return,
        max_drawdown,
        annual_sharpe
    )

# %%
for window in range(10,301,10):
    final_return,max_dd,sharpe=backtest_ma("AAPL",window)
    results.append((window,final_return,max_dd,sharpe))

# %%
results=[]
for window in range(10,301,10):
    final_return,max_dd,sharpe=backtest_ma("AAPL",window)
    results.append((window,final_return,max_dd,sharpe))

# %%
results_df=pd.DataFrame(results,culumns=["Window","Return","MaxDD","Sharpe"])

# %%
results_df=pd.DataFrame(results,columns=["Window","Return","MaxDD","Sharpe"])

# %%
results_df.sort_values("Sharpe",ascending=False).head(10)

# %%
tickers=["RKLB","AAPL","NVDA","PLTR"]

# %%
results=[]
for ticker in tickers:
    print(ticker)
    for window in range(10,301,10):
        final_return,max_dd,sharpe=backtest_ma(ticker,window)
        results.append((ticker,window,final_return,max_dd,sharpe)

# %%
results=[]
for ticker in tickers:
    print(ticker)
    for window in range(10,301,10):
        final_return,max_dd,sharpe=backtest_ma(ticker,window)
        results.append((ticker,window,final_return,max_dd,sharpe))

# %%
results_df=pd.DataFrame(results,columns=["Ticker","Window","Return","MaxDD","Sharpe"])

# %%
results_df.sort_values("Sharpe",ascending=False).head(20)

# %%
len(range(10,301,10))

# %%
len(results_df)

# %%
window_summary=(results.df.groupby("window")["Sharpe"].mean()

# %%
window_summary=(results.df.groupby("window")["Sharpe"].mean())

# %%
window_summary=(results_df.groupby("window")["Sharpe"].mean())

# %%
window_summary=(results_df.groupby("Window")["Sharpe"].mean())

# %%
results_summary

# %%
window_summary

# %%
window_summary.sort_values(ascending=False).head(10)

# %%
ticker=["AAPL","NVDA","PLTR","RKLB","CRWD","NET","DDOG","S","IOT","TSLA"]

# %%
tickers=["AAPL","NVDA","PLTR","RKLB","CRWD","NET","DDOG","S","IOT","TSLA"]

# %%
results=[]
for ticker in tickers:
    print(ticker)
    for window in range(10,301,10):
        final_return,max_dd,sharpe=backtest_ma(ticker,window)
        results.append((ticker,window,final_return,max_dd,sharpe))

# %%
results_df=pd.DataFrame(results,columns=["Ticker","window","MaxDD","Sharpe"])

# %%
results_df

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np

# %%
results_df=pd.DataFrame(results,columns=["Ticker","window","MaxDD","Sharpe"])

# %%
results_df=pd.DataFrame(results,columns=["Ticker","Window","Return","MaxDD","Sharpe"])

# %%
results_df

# %%
window_summary=(results_df.groupby("Window")["Sharpe"].mean())

# %%
window_summary

# %%
window_summary.sort_values(ascending=False).head(10)

# %%
window_median=(results_df.groupby("Window")["Sharpe"].median())

# %%
window_median.sort_values(ascending=False).head(10)

# %%
results_df[results_df["Window"]==220].sort_values("Sharpe",ascending=False)

# %%
results_df.groupby("Ticker")["Sharpe"].max()

# %%
results_df.sort_values("Sharpe",ascending=False).head()

# %%
results_df.sort_values("Sharpe",ascending=False).head(20)

# %%
def backtest_buy_hold(ticker):

    df = yf.download(ticker, period="5y")

    close = df["Close"][ticker]

    returns = close.pct_change()

    cumulative_returns = (1 + returns).cumprod()

    rolling_max = cumulative_returns.cummax()

    drawdown = cumulative_returns / rolling_max - 1

    max_drawdown = drawdown.min()

    annual_sharpe = (
        returns.mean()
        / returns.std()
        * np.sqrt(252)
    )

    final_return = cumulative_returns.iloc[-1]

    return (
        final_return,
        max_drawdown,
        annual_sharpe
    )

# %%
backtest_buy_hold("NVDA")

# %%
backtest_buy_hold("PLTR")

# %%
backtest_buy_hold("RKLB")

# %%
tickers=["CRWD","NET","DDOG","IOT","S","TSLA"]

# %%
for ticker in tickers:
    print(ticker,backtest_buy_hold(ticker))

# %%
backtest_buy_hold("AAPL")

# %%
close / close.shift(126) - 1

# %%
df=yf.download("NVDA",period="5y")

# %%
close=df["Close"]["NVDA"]

# %%
momentum=close/close.shift(126)-1

# %%
momentum.tail()

# %%
def calculate_momentum(ticker,window):
    df=yf.download(ticker,period="5y")
    close=df["Close"][ticker]
    momentum=close/close.shift(window)-1
    return momentum

# %%
calculate_momentum("NVIDA",126)

# %%
calculate_momentum("NVDA",126)

# %%
momentum=close/close.shift(window)-1

# %%
signal=momentum>0

# %%
momentum.tail()

# %%
window

# %%
window=126
momentum=close/close(window)-1
signal=momentum>0

# %%
window=126
momentum=close/close.shift(window)-1
signal=momentum>0

# %%
momentum

# %%
def backtest_momentum(ticker, window, threshold):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns=close.pct_change()
    momentum=close/close.shift(window)-1
    signal=momentum>threshold
    strategy_returns=returns*signal.shift(1)
    cumulative_returns=(1+strategy_returns).cumprod()
    rolling_max=cumlative_returns.cummax()
    drawdown=cumulative_returns/rolling_max-1
    max_drawdown=drawdown.min()
    annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
    final_return=cumulative_returns.iloc[-1]
    return(final_return,max_drawdown,annual_sharpe)

# %%
backtest_momentum("NNDA",126,0.10)

# %%
def backtest_momentum(ticker, window, threshold):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns=close.pct_change()
    momentum=close/close.shift(window)-1
    signal=momentum>threshold
    strategy_returns=returns*signal.shift(1)
    cumulative_returns=(1+strategy_returns).cumprod()
    rolling_max=cumulative_returns.cummax()
    drawdown=cumulative_returns/rolling_max-1
    max_drawdown=drawdown.min()
    annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
    final_return=cumulative_returns.iloc[-1]
    return(final_return,max_drawdown,annual_sharpe)

# %%
backtest_momentum("NNDA",126,0.10)

# %%
backtest_momentum("NVDA",126,0.10)

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tickers = ["AAPL","NVDA","PLTR","RKLB","CRWD","NET","DDOG","IOT","S","TSLA"]

# %%
resluts=[]
for ticker in tickers:
     print(ticker)
    final_return,max_dd,sharpe = backtest_momentum(ticker,126,0.10)
    results.append([tiker,final_return,max_dd,sharpe])
results_df = pd.DataFrame(results,columns=["Ticker","Return","MaxDD","Sharpe"])
results_df=(results_df.sort_values("Sharpe",ascending=False).reset_index(drop=True))
results_df

# %%
results = []

for ticker in tickers:
    print(ticker)

    final_return, max_dd, sharpe = backtest_momentum(
        ticker,
        126,
        0.10
    )

    results.append([
        ticker,
        final_return,
        max_dd,
        sharpe
    ])

results_df = pd.DataFrame(
    results,
    columns=["Ticker", "Return", "MaxDD", "Sharpe"]
)

results_df = (
    results_df
    .sort_values("Sharpe", ascending=False)
    .reset_index(drop=True)
)

results_df

# %%
def backtest_momentum(ticker, window, threshold):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns=close.pct_change()
    momentum=close/close.shift(window)-1
    signal=momentum>threshold
    strategy_returns=returns*signal.shift(1)
    cumulative_returns=(1+strategy_returns).cumprod()
    rolling_max=cumulative_returns.cummax()
    drawdown=cumulative_returns/rolling_max-1
    max_drawdown=drawdown.min()
    annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
    final_return=cumulative_returns.iloc[-1]
    return(final_return,max_drawdown,annual_sharpe)

# %%
results = []

for ticker in tickers:
    print(ticker)

    final_return, max_dd, sharpe = backtest_momentum(
        ticker,
        126,
        0.10
    )

    results.append([
        ticker,
        final_return,
        max_dd,
        sharpe
    ])

results_df = pd.DataFrame(
    results,
    columns=["Ticker", "Return", "MaxDD", "Sharpe"]
)

results_df = (
    results_df
    .sort_values("Sharpe", ascending=False)
    .reset_index(drop=True)
)

results_df

# %%
backtest_ma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 backtest_ma
#
# NameError: name 'backtest_ma' is not defined

# %%
backtest_buy_hold
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 backtest_buy_hold
#
# NameError: name 'backtest_buy_hold' is not defined

# %%
backtest_ma
# Out:
# <function __main__.backtest_ma(ticker, window)>

# %%
backtest_buy_hold
# Out:
# <function __main__.backtest_buy_hold(ticker)>

# %%
backtest_momentum
# Out:
# <function __main__.backtest_momentum(ticker, window, threshold)>

# %%
results_df
# Out:
#   Ticker     Return     MaxDD    Sharpe
# 0   PLTR  10.646697 -0.406115  1.261666
# 1   NVDA   5.398843 -0.283959  1.089315
# 2   RKLB   9.713856 -0.546740  1.038565
# 3   CRWD   3.063852 -0.321723  0.895175
# 4    NET   1.756519 -0.449972  0.490239
# 5    IOT   1.605030 -0.330651  0.457934
# 6   DDOG   1.047234 -0.393164  0.181011
# 7   TSLA   0.776286 -0.613423  0.044766
# 8   AAPL   0.898885 -0.266025 -0.095639
# 9      S   0.505100 -0.589297 -0.356843

# %%
results=[]
for window in range(21,253,21):
    sharpes=[]
    for ticker in tickers:
        final_return,max_dd,sharpe=backtest_momentum(ticker,window,0.10)
        sharpes.append(sharpe)
    np.mean(sharpes)
    results.append([window,np.mean(sharpes)])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
results_df = pd.DataFrame(
    results,
    columns=["Window","Sharpe_Mean"]
# Out:
#   Cell In[30], line 3
#     columns=["Window","Sharpe_Mean"]
#                                     ^
# SyntaxError: incomplete input

# %%
results_df = pd.DataFrame(
    results,
    columns=["Window","Sharpe_Mean"])

# %%
results_df
# Out:
#     Window  Sharpe_Mean
# 0       21     0.441648
# 1       42     0.309026
# 2       63     0.404504
# 3       84     0.322921
# 4      105     0.435387
# 5      126     0.511781
# 6      147     0.436568
# 7      168     0.509622
# 8      189     0.384018
# 9      210     0.547923
# 10     231     0.548128
# 11     252     0.657912

# %%
results_df = (
    results_df
    .sort_values("Sharpe_Mean", ascending=False)
    .reset_index(drop=True)
)

# %%
results_df
# Out:
#     Window  Sharpe_Mean
# 0      252     0.657912
# 1      231     0.548128
# 2      210     0.547923
# 3      126     0.511781
# 4      168     0.509622
# 5       21     0.441648
# 6      147     0.436568
# 7      105     0.435387
# 8       63     0.404504
# 9      189     0.384018
# 10      84     0.322921
# 11      42     0.309026

# %%
results=[]
for window in range(21,253,21):
    sharpes=[]
    for ticker in tickers:
        final_return,max_dd,sharpe=backtest_momentum(ticker,window,0.10)
        sharpes.append(sharpe)
    mean_sharpe=np.mean(sharpes)
    median_sharpe=np.median(sharpes)
    results.append([window,mean_sharpe,median_sharpe])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
results_df=pd.DataFrame(results,column="Window","Sharpe_Mean","Sharpe_Median")
# Out:
#   Cell In[36], line 1
#     results_df=pd.DataFrame(results,column="Window","Sharpe_Mean","Sharpe_Median")
#                                                                                  ^
# SyntaxError: positional argument follows keyword argument

# %%
results_df=pd.DataFrame(results,column=["Window","Sharpe_Mean","Sharpe_Median"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 results_df=pd.DataFrame(results,column=["Window","Sharpe_Mean","Sharpe_Median"])
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'column'

# %%
results_df=pd.DataFrame(results,columns=["Window","Sharpe_Mean","Sharpe_Median"])

# %% [markdown]
# results_df

# %%
results_df=results_df.sort_values("Sharpe_Mean",ascending=False).reset_index(drop=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 results_df=results_df.sort_values("Sharpe_Mean",ascending=False).reset_index(drop=true)
#
# NameError: name 'true' is not defined

# %%
results_df=results_df.sort_values("Sharpe_Mean",ascending=False).reset_index(drop=True)

# %%
results_df
# Out:
#     Window  Sharpe_Mean  Sharpe_Median
# 0      252     0.667906       0.723211
# 1      231     0.563513       0.583698
# 2      210     0.559418       0.635535
# 3      168     0.543905       0.499233
# 4      126     0.523243       0.489620
# 5      105     0.477097       0.391305
# 6      147     0.466656       0.456600
# 7       21     0.461408       0.474316
# 8       63     0.404568       0.390395
# 9      189     0.392601       0.445853
# 10      84     0.355685       0.131102
# 11      42     0.344097       0.426327

# %%
results=[]
for threshold in range(0,0.2,0.05):
    sharpes=[]
    for ticker in tickers: 
        final_return,max_dd,sharpe=backtest_momentum(ticker,252,threshold)
        shapes.append(sharpe)
    sharpe_mean=np.mean(sharpes)
    sharpe_median=np.median(sharpes)
    results.append(["threshold","sharpe_mean","sharpe_median"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 results=[]
# ----> 2 for threshold in range(0,0.2,0.05):
#       3     sharpes=[]
#       4     for ticker in tickers:
#       5         final_return,max_dd,sharpe=backtest_momentum(ticker,252,threshold)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
results=[]
threshols=[0,0.05,0.1,0.15,0.2]
for threshold in thresholds:
    sharpes=[]
    for ticker in tickers: 
        final_return,max_dd,sharpe=backtest_momentum(ticker,252,threshold)
        sharpes.append(sharpe)
    sharpe_mean=np.mean(sharpes)
    sharpe_median=np.median(sharpes)
    results.append([threshold,sharpe_mean,sharpe_median])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 3
#       1 results=[]
#       2 threshols=[0,0.05,0.1,0.15,0.2]
# ----> 3 for threshold in thresholds:
#       4     sharpes=[]
#       5     for ticker in tickers:
#       6         final_return,max_dd,sharpe=backtest_momentum(ticker,252,threshold)
#
# NameError: name 'thresholds' is not defined

# %%
results=[]
thresholds=[0,0.05,0.1,0.15,0.2]
for threshold in thresholds:
    sharpes=[]
    for ticker in tickers: 
        final_return,max_dd,sharpe=backtest_momentum(ticker,252,threshold)
        sharpes.append(sharpe)
    sharpe_mean=np.mean(sharpes)
    sharpe_median=np.median(sharpes)
    results.append([threshold,sharpe_mean,sharpe_median])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
results_df=pd.DataFrame(results,columns=["Threshold","Sarpe_Mean","Sharpe_Median"])
results_df=results_df.sort_values("Sharpe_Mean",ascending=False).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 2
#       1 results_df=pd.DataFrame(results,columns=["Threshold","Sarpe_Mean","Sharpe_Median"])
# ----> 2 results_df=results_df.sort_values("Sharpe_Mean",ascending=False).reset_index(drop=True)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\frame.py:8347, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8343             )
#    8344         elif by:
#    8345             # len(by) == 1
#    8346
# -> 8347             k = self._get_label_or_level_values(by[0], axis=axis)
#    8348
#    8349             # need to rewrap column in Series to apply key function
#    8350             if key is not None:
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\generic.py:1776, in NDFrame._get_label_or_level_values(self, key, axis)
#    1772             values = self.xs(key, axis=first_other_axes)._values
#    1773         elif self._is_level_reference(key, axis=axis):
#    1774             values = self.axes[axis].get_level_values(key)._values
#    1775         else:
# -> 1776             raise KeyError(key)
#    1777
#    1778         # Check for duplicates
#    1779         if values.ndim > 1:
#
# KeyError: 'Sharpe_Mean'

# %%
results_df=pd.DataFrame(results,columns=["Threshold","Sharpe_Mean","Sharpe_Median"])
results_df=results_df.sort_values("Sharpe_Mean",ascending=False).reset_index(drop=True)

# %%
results_df
# Out:
#    Threshold  Sharpe_Mean  Sharpe_Median
# 0       0.00     0.792777       0.914275
# 1       0.05     0.719467       0.781526
# 2       0.10     0.667906       0.723211
# 3       0.15     0.644785       0.763820
# 4       0.20     0.627647       0.677473

# %%
backtest_buy_hold()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 backtest_buy_hold()
#
# NameError: name 'backtest_buy_hold' is not defined

# %%
backtest_momentum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 backtest_momentum()
#
# NameError: name 'backtest_momentum' is not defined

# %%
backtest_buy_hold()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 backtest_buy_hold()
#
# TypeError: backtest_buy_hold() missing 1 required positional argument: 'ticker'

# %%
results=[]
buy_hold_result=backtest_buy_hold("NVDA")
ma_result=backtest_ma("NVDA",240)
momentum_result=backtest_momentum("NVDA",252,0.00)
#Buy&Hold
final_return,max_dd,sharpe=buy_hold_result
results.append(["Buy & Hold",final_return,max_dd,sharpe])
#MA
final_return,max_dd,sharpe=ma_result
results.append(["MA240",final_return,max_dd,sharpe])
#Momentum
final_return,max_dd,sharpe=momentum_result
results.append(["Momentum252",final_return,max_dd,sharpe])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 results=[]
# ----> 2 buy_hold_result=backtest_buy_hold("NVDA")
#       3 ma_result=backtest_ma("NVDA",240)
#       4 momentum_result=backtest_momentum("NVDA",252,0.00)
#       5 #Buy&Hold
#
# Cell In[3], line 3, in backtest_buy_hold(ticker)
#       1 def backtest_buy_hold(ticker):
#       2
# ----> 3     df = yf.download(ticker, period="5y")
#       4
#       5     close = df["Close"][ticker]
#       6
#
# NameError: name 'yf' is not defined

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
results=[]
buy_hold_result=backtest_buy_hold("NVDA")
ma_result=backtest_ma("NVDA",240)
momentum_result=backtest_momentum("NVDA",252,0.00)
#Buy&Hold
final_return,max_dd,sharpe=buy_hold_result
results.append(["Buy & Hold",final_return,max_dd,sharpe])
#MA
final_return,max_dd,sharpe=ma_result
results.append(["MA240",final_return,max_dd,sharpe])
#Momentum
final_return,max_dd,sharpe=momentum_result
results.append(["Momentum252",final_return,max_dd,sharpe])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 results=[]
#       2 buy_hold_result=backtest_buy_hold("NVDA")
#       3 ma_result=backtest_ma("NVDA",240)
# ----> 4 momentum_result=backtest_momentum("NVDA",252,0.00)
#       5 #Buy&Hold
#       6 final_return,max_dd,sharpe=buy_hold_result
#       7 results.append(["Buy & Hold",final_return,max_dd,sharpe])
#
# Cell In[5], line 9, in backtest_momentum(ticker, window, threshold)
#       5     momentum=close/close.shift(window)-1
#       6     signal=momentum>threshold
#       7     strategy_returns=returns*signal.shift(1)
#       8     cumulative_returns=(1+strategy_returns).cumprod()
# ----> 9     rolling_max=cumlative_returns.cummax()
#      10     drawdown=cumulative_returns/rolling_max-1
#      11     max_drawdown=drawdown.min()
#      12     annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
#
# NameError: name 'cumlative_returns' is not defined

# %%
results=[]
buy_hold_result=backtest_buy_hold("NVDA")
ma_result=backtest_ma("NVDA",240)
momentum_result=backtest_momentum("NVDA",252,0.00)
#Buy&Hold
final_return,max_dd,sharpe=buy_hold_result
results.append(["Buy & Hold",final_return,max_dd,sharpe])
#MA
final_return,max_dd,sharpe=ma_result
results.append(["MA240",final_return,max_dd,sharpe])
#Momentum
final_return,max_dd,sharpe=momentum_result
results.append(["Momentum252",final_return,max_dd,sharpe])
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
results_df=pd.DataFrame(results,columns=["Strategy","Return","MaxDD","Sharpe"])
results_df=results_df.sort_values("Sharpe",ascending=False).reset_index(drop=True)

# %%
results_df
# Out:
#       Strategy     Return     MaxDD    Sharpe
# 0        MA240   9.586923 -0.270468  1.381871
# 1  Momentum252   8.054531 -0.368810  1.262466
# 2   Buy & Hold  10.650830 -0.663351  1.174885

# %%
results=[]
for ticker in tickers:
    buy_hold_result=backtest_buy_hold(ticker)
    ma_result=backtest_ma(ticker,240)
    momentum_result=backtest_momentum(ticker,252,0.00)
    #Buy&Hold
    final_return,max_dd,sharpe=buy_hold_result
    results.append([ticker,"Buy & Hold",final_return,max_dd,sharpe])
    #MA
    final_return,max_dd,sharpe=ma_result
    results.append([ticker,"MA240",final_return,max_dd,sharpe])
    #Momentum
    final_return,max_dd,sharpe=momentum_result
    results.append([ticker,"Momentum252",final_return,max_dd,sharpe])
results_df=pd.DataFrame(results,columns=["Ticker","Strategy","Return","MaxDD","Sharpe"])
results_df=results_df.sort_values("Sharpe",ascending=False).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 results=[]
# ----> 2 for ticker in tickers:
#       3     buy_hold_result=backtest_buy_hold(ticker)
#       4     ma_result=backtest_ma(ticker,240)
#       5     momentum_result=backtest_momentum(ticker,252,0.00)
#
# NameError: name 'tickers' is not defined

# %%
results=[]
for ticker in tickers:
    buy_hold_result=backtest_buy_hold(ticker)
    ma_result=backtest_ma(ticker,240)
    momentum_result=backtest_momentum(ticker,252,0.00)
    #Buy&Hold
    final_return,max_dd,sharpe=buy_hold_result
    results.append([ticker,"Buy & Hold",final_return,max_dd,sharpe])
    #MA
    final_return,max_dd,sharpe=ma_result
    results.append([ticker,"MA240",final_return,max_dd,sharpe])
    #Momentum
    final_return,max_dd,sharpe=momentum_result
    results.append([ticker,"Momentum252",final_return,max_dd,sharpe])
results_df=pd.DataFrame(results,columns=["Ticker","Strategy","Return","MaxDD","Sharpe"])
results_df=results_df.sort_values("Sharpe",ascending=False).reset_index(drop=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
results_df
# Out:
#    Ticker     Strategy     Return     MaxDD    Sharpe
# 0    NVDA        MA240   9.933152 -0.270468  1.399969
# 1    PLTR  Momentum252  13.601637 -0.406115  1.280538
# 2    NVDA  Momentum252   8.346587 -0.368810  1.280183
# 3    NVDA   Buy & Hold  10.931323 -0.663351  1.184776
# 4    PLTR        MA240  10.200388 -0.436562  1.183846
# 5    RKLB        MA240   8.973046 -0.628026  1.005165
# 6    CRWD  Momentum252   3.739826 -0.444371  0.941211
# 7    RKLB  Momentum252   7.000577 -0.562404  0.924433
# 8    DDOG  Momentum252   3.630449 -0.351005  0.888051
# 9     NET  Momentum252   4.017875 -0.449972  0.863583
# 10   RKLB   Buy & Hold   6.616332 -0.829633  0.862044
# 11   PLTR   Buy & Hold   5.748528 -0.791449  0.857703
# 12   AAPL   Buy & Hold   2.267537 -0.333605  0.730473
# 13   CRWD        MA240   2.399734 -0.458887  0.702109
# 14   AAPL        MA240   1.677172 -0.256574  0.668642
# 15   CRWD   Buy & Hold   2.844434 -0.676922  0.666954
# 16    IOT        MA240   2.222423 -0.469128  0.628597
# 17    NET   Buy & Hold   2.352378 -0.825823  0.593746
# 18   DDOG   Buy & Hold   2.244828 -0.681064  0.563049
# 19   TSLA   Buy & Hold   1.746558 -0.736322  0.483918
# 20    IOT   Buy & Hold   1.362753 -0.703779  0.425336
# 21   DDOG        MA240   1.538451 -0.386196  0.417652
# 22    IOT  Momentum252   1.476420 -0.531135  0.406589
# 23   AAPL  Momentum252   1.363865 -0.333605  0.393773
# 24    NET        MA240   1.455932 -0.505652  0.392315
# 25      S  Momentum252   1.369954 -0.353795  0.383801
# 26   TSLA  Momentum252   1.003212 -0.537657  0.202474
# 27      S   Buy & Hold   0.382876 -0.843512  0.017245
# 28   TSLA        MA240   0.658722 -0.600635 -0.040492
# 29      S        MA240   0.557196 -0.549315 -0.217413

# %%
results_df.groupby("Strategy")["Sharpe"].mean()
# Out:
# Strategy
# Buy & Hold     0.638524
# MA240          0.614039
# Momentum252    0.756464
# Name: Sharpe, dtype: float64

# %%
results_df.groupby("Strategy")["Sharpe"].median()
# Out:
# Strategy
# Buy & Hold     0.630350
# MA240          0.648619
# Momentum252    0.875817
# Name: Sharpe, dtype: float64

# %%
results_df.groupby("Strategy")["Return"].mean()
# Out:
# Strategy
# Buy & Hold     3.649755
# MA240          3.961622
# Momentum252    4.555040
# Name: Return, dtype: float64

# %%
results_df.groupby("Strategy")["Return"].median()
# Out:
# Strategy
# Buy & Hold     2.309957
# MA240          1.949798
# Momentum252    3.685137
# Name: Return, dtype: float64

# %%
results_df.groupby("Strategy")["MaxDD"].mean()
# Out:
# Strategy
# Buy & Hold    -0.708546
# MA240         -0.456144
# Momentum252   -0.433887
# Name: MaxDD, dtype: float64

# %%
results_df.groupby("Strategy")["MaxDD"].median()
# Out:
# Strategy
# Buy & Hold    -0.720051
# MA240         -0.464008
# Momentum252   -0.425243
# Name: MaxDD, dtype: float64

# %%
results_df.groupby("Strategy")[["Return", "MaxDD", "Sharpe"]].mean()
# Out:
#                Return     MaxDD    Sharpe
# Strategy
# Buy & Hold   3.649755 -0.708546  0.638524
# MA240        3.961622 -0.456144  0.614039
# Momentum252  4.555040 -0.433887  0.756464

# %%
results_df.groupby("Strategy")[["Return", "MaxDD", "Sharpe"]].median()
# Out:
#                Return     MaxDD    Sharpe
# Strategy
# Buy & Hold   2.309957 -0.720051  0.630350
# MA240        1.949798 -0.464008  0.648619
# Momentum252  3.685137 -0.425243  0.875817

# %%
import yfinance as yf
import pandas as pd
import matplotlib pyplot as plt
import pandas as pd
# Out:
#   Cell In[1], line 3
#     import matplotlib pyplot as plt
#                       ^
# SyntaxError: invalid syntax

# %%
import yfinance as yf
import pandas as pd
import matplotlib piplot as plt
import pandas as pd
# Out:
#   Cell In[2], line 3
#     import matplotlib piplot as plt
#                       ^
# SyntaxError: invalid syntax

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd

# %%
backtest_buy_hold()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 backtest_buy_hold()
#
# TypeError: backtest_buy_hold() missing 1 required positional argument: 'ticker'

# %%
def backtest_buy_hold(ticker):

    df = yf.download(ticker, period="5y")

    close = df["Close"][ticker]

    returns = close.pct_change()

    cumulative_returns = (1 + returns).cumprod()

    rolling_max = cumulative_returns.cummax()

    drawdown = cumulative_returns / rolling_max - 1

    max_drawdown = drawdown.min()

    annual_sharpe = (
        returns.mean()
        / returns.std()
        * np.sqrt(252)
    )

    final_return = cumulative_returns.iloc[-1]

    return {"Strategy":"Buy & Hold","Final Return":final_return,"Max Drawdown":max_drawdown,"Sharpe":annual_sharpe,}

# %%
result =backtest_buy_hold("NVIDA")
print(result)
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: NVIDA"}}}
# $NVIDA: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NVIDA']: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 result =backtest_buy_hold("NVIDA")
#       2 print(result)
#
# Cell In[8], line 20, in backtest_buy_hold(ticker)
#      16
#      17     annual_sharpe = (
#      18         returns.mean()
#      19         / returns.std()
# ---> 20         * np.sqrt(252)
#      21     )
#      22
#      23     final_return = cumulative_returns.iloc[-1]
#
# NameError: name 'np' is not defined

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import pandas as np

# %%
result =backtest_buy_hold("NVIDA")
print(result)
# Out:
# $NVIDA: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['NVIDA']: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result =backtest_buy_hold("NVIDA")
#       2 print(result)
#
# Cell In[8], line 20, in backtest_buy_hold(ticker)
#      16
#      17     annual_sharpe = (
#      18         returns.mean()
#      19         / returns.std()
# ---> 20         * np.sqrt(252)
#      21     )
#      22
#      23     final_return = cumulative_returns.iloc[-1]
#
# AttributeError: module 'pandas' has no attribute 'sqrt'

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
result =backtest_buy_hold("NVDA")
print(result)
# Out:
# [*********************100%***********************]  1 of 1 completed
# {'Strategy': 'Buy & Hold', 'Final Return': np.float64(10.490361979708974), 'Max Drawdown': np.float64(-0.6633509152593063), 'Sharpe': np.float64(1.1673848887991447)}

# %%
def backtest_ma(ticker, window):

    df = yf.download(ticker, period="5y")

    close = df["Close"][ticker]

    returns = close.pct_change()

    ma = close.rolling(window).mean()

    signal = close > ma

    strategy_returns = (
        signal.shift(1)
        .fillna(False)
        .astype(int)
        * returns
    )

    cumulative_returns = (
        1 + strategy_returns
    ).cumprod()

    rolling_max = cumulative_returns.cummax()

    drawdown = (
        cumulative_returns
        / rolling_max
        - 1
    )

    max_drawdown = drawdown.min()

    annual_sharpe = (
        strategy_returns.mean()
        / strategy_returns.std()
        * np.sqrt(252)
    )

    final_return = cumulative_returns.iloc[-1]

    return {"Strategy":"Moving Average","Final Return":final_return,"Max Drawdown":max_drawdown,"Sharpe":annual_sharpe}

# %%
def backtest_momentum(ticker, window, threshold):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns=close.pct_change()
    momentum=close/close.shift(window)-1
    signal=momentum>threshold
    strategy_returns=returns*signal.shift(1)
    cumulative_returns=(1+strategy_returns).cumprod()
    rolling_max=cumlative_returns.cummax()
    drawdown=cumulative_returns/rolling_max-1
    max_drawdown=drawdown.min()
    annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
    final_return=cumulative_returns.iloc[-1]
    return {"Strategy":"Momentum","Final Return":final_return,"Max Drawdown":max_drawdown,"Sharpe":annual_sharpe}

# %%
result =backtest_ma("NVDA")
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 result =backtest_ma("NVDA")
#       2 print(result)
#
# TypeError: backtest_ma() missing 1 required positional argument: 'window'

# %%
results=[
    backtest_buy_hold("NVDA"),
    backtest_ma("NVDA"),
    backtest_momentum("NVDA"),]
results_df=pd.Dateframe(results)
results_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 results=[
#       2     backtest_buy_hold("NVDA"),
# ----> 3     backtest_ma("NVDA"),
#       4     backtest_momentum("NVDA"),]
#       5 results_df=pd.Dateframe(results)
#       6 results_df
#
# TypeError: backtest_ma() missing 1 required positional argument: 'window'

# %%
results=[
    backtest_buy_hold("NVDA"),
    backtest_ma("NVDA",240),
    backtest_momentum("NVDA",252,0.00),]
results_df=pd.Dateframe(results)
results_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 results=[
#       2     backtest_buy_hold("NVDA"),
#       3     backtest_ma("NVDA",240),
# ----> 4     backtest_momentum("NVDA",252,0.00),]
#       5 results_df=pd.Dateframe(results)
#       6 results_df
#
# Cell In[16], line 9, in backtest_momentum(ticker, window, threshold)
#       5     momentum=close/close.shift(window)-1
#       6     signal=momentum>threshold
#       7     strategy_returns=returns*signal.shift(1)
#       8     cumulative_returns=(1+strategy_returns).cumprod()
# ----> 9     rolling_max=cumlative_returns.cummax()
#      10     drawdown=cumulative_returns/rolling_max-1
#      11     max_drawdown=drawdown.min()
#      12     annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
#
# NameError: name 'cumlative_returns' is not defined

# %%
def backtest_momentum(ticker, window, threshold):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns=close.pct_change()
    momentum=close/close.shift(window)-1
    signal=momentum>threshold
    strategy_returns=returns*signal.shift(1)
    cumulative_returns=(1+strategy_returns).cumprod()
    rolling_max=cumulative_returns.cummax()
    drawdown=cumulative_returns/rolling_max-1
    max_drawdown=drawdown.min()
    annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
    final_return=cumulative_returns.iloc[-1]
    return {"Strategy":"Momentum","Final Return":final_return,"Max Drawdown":max_drawdown,"Sharpe":annual_sharpe}

# %%
results=[
    backtest_buy_hold("NVDA"),
    backtest_ma("NVDA",240),
    backtest_momentum("NVDA",252,0.00),]
results_df=pd.Dateframe(results)
results_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 5
#       1 results=[
#       2     backtest_buy_hold("NVDA"),
#       3     backtest_ma("NVDA",240),
#       4     backtest_momentum("NVDA",252,0.00),]
# ----> 5 results_df=pd.Dateframe(results)
#       6 results_df
#
# AttributeError: module 'pandas' has no attribute 'Dateframe'

# %%
results=[
    backtest_buy_hold("NVDA"),
    backtest_ma("NVDA",240),
    backtest_momentum("NVDA",252,0.00),]
results_df=pd.Dataframe(results)
results_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 5
#       1 results=[
#       2     backtest_buy_hold("NVDA"),
#       3     backtest_ma("NVDA",240),
#       4     backtest_momentum("NVDA",252,0.00),]
# ----> 5 results_df=pd.Dataframe(results)
#       6 results_df
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
results=[
    backtest_buy_hold("NVDA"),
    backtest_ma("NVDA",240),
    backtest_momentum("NVDA",252,0.00),]
results_df=pd.DataFrame(results)
results_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#          Strategy  Final Return  Max Drawdown    Sharpe
# 0      Buy & Hold     10.481751     -0.663351  1.167078
# 1  Moving Average      9.383657     -0.270468  1.365973
# 2        Momentum      8.092456     -0.368810  1.260760

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
tickers=["ALAB",  #Astera Labs
         "HMW",   #Howmet Aerospace
         "ICHR",  #Ichor Holdings
         "RKLB",  #Rocket Lab]
# Out:
#   Cell In[5], line 4
#     "RKLB",  #Rocket Lab]
#                          ^
# SyntaxError: incomplete input

# %%
tickers=["ALAB",  #Astera Labs
         "HMW",   #Howmet Aerospace
         "ICHR",  #Ichor Holdings
         "RKLB",  #Rocket Lab
        ]

# %%
for ticker in tickers:
    print(ticker)

    results=[
        backtest_buy_hold(ticer),
        backtest_ma(ticker,240),
        backtest_momentum(ticker,252,0.00)
    ]

    print(pd.DataFrame(results))
# Out:
# ALAB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 for ticker in tickers:
#       2     print(ticker)
#       3
#       4     results=[
# ----> 5         backtest_buy_hold(ticer),
#       6         backtest_ma(ticker,240),
#       7         backtest_momentum(ticker,252,0.00)
#       8     ]
#
# NameError: name 'ticer' is not defined

# %%
for ticker in tickers:
    print(ticker)

    results=[
        backtest_buy_hold(ticer),
        backtest_ma(ticker,240),
        backtest_momentum(ticker,252,0.00)
    ]

    print(pd.DataFrame(results))
# Out:
# ALAB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#          Strategy  Final Return  Max Drawdown    Sharpe
# 0      Buy & Hold      5.447364     -0.636925  1.221664
# 1  Moving Average      3.574489     -0.497459  1.132080
# 2        Momentum      3.819379     -0.601914  1.149817
# HMW
# $HMW: possibly delisted; no price data found  (period=5y)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['HMW']: possibly delisted; no price data found  (period=5y)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 for ticker in tickers:
#       2     print(ticker)
#       3
#       4     results=[
# ----> 5         backtest_buy_hold(ticker),
#       6         backtest_ma(ticker,240),
#       7         backtest_momentum(ticker,252,0.00)
#       8     ]
#
# Cell In[4], line 23, in backtest_buy_hold(ticker)
#      19         / returns.std()
#      20         * np.sqrt(252)
#      21     )
#      22
# ---> 23     final_return = cumulative_returns.iloc[-1]
#      24
#      25     return {"Strategy":"Buy & Hold","Final Return":final_return,"Max Drawdown":max_drawdown,"Sharpe":annual_sharpe,}
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\indexing.py:1773, in _iLocIndexer._getitem_axis(self, key, axis)
#    1770     raise TypeError("Cannot index by location index with a non-integer key")
#    1772 # validate the location
# -> 1773 self._validate_integer(key, axis)
#    1775 return self.obj._ixs(key, axis=axis)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\indexing.py:1706, in _iLocIndexer._validate_integer(self, key, axis)
#    1704 len_axis = len(self.obj._get_axis(axis))
#    1705 if key >= len_axis or key < -len_axis:
# -> 1706     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
tickers=["ALAB",  #Astera Labs
         "HWM",   #Howmet Aerospace
         "ICHR",  #Ichor Holdings
         "RKLB",  #Rocket Lab
        ]

# %%
for ticker in tickers:
    print(ticker)

    results=[
        backtest_buy_hold(ticer),
        backtest_ma(ticker,240),
        backtest_momentum(ticker,252,0.00)
    ]

    print(pd.DataFrame(results))
# Out:
# ALAB
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       1 for ticker in tickers:
#       2     print(ticker)
#       3
#       4     results=[
# ----> 5         backtest_buy_hold(ticer),
#       6         backtest_ma(ticker,240),
#       7         backtest_momentum(ticker,252,0.00)
#       8     ]
#
# NameError: name 'ticer' is not defined

# %%
for ticker in tickers:
    print(ticker)

    results=[
        backtest_buy_hold(ticker),
        backtest_ma(ticker,240),
        backtest_momentum(ticker,252,0.00)
    ]

    print(pd.DataFrame(results))
# Out:
# ALAB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#          Strategy  Final Return  Max Drawdown    Sharpe
# 0      Buy & Hold      5.427374     -0.636925  1.220055
# 1  Moving Average      3.561371     -0.497459  1.129866
# 2        Momentum      3.805363     -0.601914  1.147703
# HWM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#          Strategy  Final Return  Max Drawdown    Sharpe
# 0      Buy & Hold      9.317000     -0.201394  1.563378
# 1  Moving Average      8.145999     -0.194132  1.660380
# 2        Momentum      7.275817     -0.232037  1.571655
# ICHR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#          Strategy  Final Return  Max Drawdown    Sharpe
# 0      Buy & Hold      1.455777     -0.718293  0.462201
# 1  Moving Average      2.490302     -0.445582  0.641075
# 2        Momentum      1.344058     -0.576372  0.346808
# RKLB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#          Strategy  Final Return  Max Drawdown    Sharpe
# 0      Buy & Hold      7.654644     -0.829633  0.897622
# 1  Moving Average      9.332665     -0.628026  1.017620
# 2        Momentum      7.477933     -0.609931  0.942457

# %%
def backtest_buy_hold(ticker):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns = close.pct_change()
    cumulative_returns = (1 + returns).cumprod()
    rolling_max = cumulative_returns.cummax()
    drawdown = cumulative_returns / rolling_max - 1
    max_drawdown = drawdown.min()
    annual_sharpe = (
        returns.mean()
        / returns.std()
        * np.sqrt(252)
    )
    final_return = cumulative_returns.iloc[-1]
    return {"Ticker":ticker,
            "Strategy":"Buy & Hold",
            "Final Return":final_return,
            "Max Drawdown":max_drawdown,
            "Sharpe":annual_sharpe,
    }

# %%
def backtest_momentum(ticker, window, threshold):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns=close.pct_change()
    momentum=close/close.shift(window)-1
    signal=momentum>threshold
    strategy_returns=returns*signal.shift(1)
    cumulative_returns=(1+strategy_returns).cumprod()
    rolling_max=cumlative_returns.cummax()
    drawdown=cumulative_returns/rolling_max-1
    max_drawdown=drawdown.min()
    annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
    final_return=cumulative_returns.iloc[-1]
    return {"Ticker":ticker,
            "Strategy":"Momentum",
            "Final Return":final_return,
            "Max Drawdown":max_drawdown,
            "Sharpe":annual_sharpe
    }

# %%
def backtest_ma(ticker, window):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns = close.pct_change()
    ma = close.rolling(window).mean()
    signal = close > ma
    strategy_returns = (
        signal.shift(1)
        .fillna(False)
        .astype(int)
        * returns
    )
    cumulative_returns = (
        1 + strategy_returns
    ).cumprod()
    rolling_max = cumulative_returns.cummax()
    drawdown = (
        cumulative_returns
        / rolling_max
        - 1
    )
    max_drawdown = drawdown.min()
    annual_sharpe = (
        strategy_returns.mean()
        / strategy_returns.std()
        * np.sqrt(252)
    )
    final_return = cumulative_returns.iloc[-1]
    return {"Ticker":ticker,
            "Strategy":"Moving Average",
            "Final Return":final_return,
            "Max Drawdown":max_drawdown,
            "Sharpe":annual_sharpe
    }

# %%
backtest_buy_hold()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 backtest_buy_hold()
#
# TypeError: backtest_buy_hold() missing 1 required positional argument: 'ticker'

# %%
backtest_buy_hold(ticker)
# Out:
# [*********************100%***********************]  1 of 1 completed
# {'Ticker': 'RKLB',
#  'Strategy': 'Buy & Hold',
#  'Final Return': np.float64(7.0250446128492),
#  'Max Drawdown': np.float64(-0.829633200368177),
#  'Sharpe': np.float64(0.8764282198834891)}

# %%
backtest_ma(ticker,period="5y")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 backtest_ma(ticker,period="5y")
#
# TypeError: backtest_ma() got an unexpected keyword argument 'period'

# %%
backtest_ma(ticker,period=240)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 backtest_ma(ticker,period=240)
#
# TypeError: backtest_ma() got an unexpected keyword argument 'period'

# %%
backtest_ma(ticker,240)
# Out:
# [*********************100%***********************]  1 of 1 completed
# {'Ticker': 'RKLB',
#  'Strategy': 'Moving Average',
#  'Final Return': np.float64(9.483863116347317),
#  'Max Drawdown': np.float64(-0.6280258988689211),
#  'Sharpe': np.float64(1.021781552390085)}

# %%
backtest_ma(ticker,252,0.00)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 backtest_ma(ticker,252,0.00)
#
# TypeError: backtest_ma() takes 2 positional arguments but 3 were given

# %%
backtest_momentum(ticker,252,0.00)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 backtest_momentum(ticker,252,0.00)
#
# Cell In[13], line 9, in backtest_momentum(ticker, window, threshold)
#       5     momentum=close/close.shift(window)-1
#       6     signal=momentum>threshold
#       7     strategy_returns=returns*signal.shift(1)
#       8     cumulative_returns=(1+strategy_returns).cumprod()
# ----> 9     rolling_max=cumlative_returns.cummax()
#      10     drawdown=cumulative_returns/rolling_max-1
#      11     max_drawdown=drawdown.min()
#      12     annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
#
# NameError: name 'cumlative_returns' is not defined

# %%
def backtest_momentum(ticker, window, threshold):
    df = yf.download(ticker, period="5y")
    close = df["Close"][ticker]
    returns=close.pct_change()
    momentum=close/close.shift(window)-1
    signal=momentum>threshold
    strategy_returns=returns*signal.shift(1)
    cumulative_returns=(1+strategy_returns).cumprod()
    rolling_max=cumulative_returns.cummax()
    drawdown=cumulative_returns/rolling_max-1
    max_drawdown=drawdown.min()
    annual_sharpe=strategy_returns.mean()/strategy_returns.std()*np.sqrt(252)
    final_return=cumulative_returns.iloc[-1]
    return {"Ticker":ticker,
            "Strategy":"Momentum",
            "Final Return":final_return,
            "Max Drawdown":max_drawdown,
            "Sharpe":annual_sharpe
    }

# %%
backtest_momentum(ticker,252,0.00)
# Out:
# [*********************100%***********************]  1 of 1 completed
# {'Ticker': 'RKLB',
#  'Strategy': 'Momentum',
#  'Final Return': 7.597151389330057,
#  'Max Drawdown': -0.6099314375246369,
#  'Sharpe': np.float64(0.9466831691968846)}

# %%
tickers
# Out:
# ['ALAB', 'HWM', 'ICHR', 'RKLB']

# %%
ticker
# Out:
# 'RKLB'

# %%
for ticker in tickers:
    print(ticker)
# Out:
# ALAB
# HWM
# ICHR
# RKLB

# %%
all_results=[]

for ticker in tickers:

    results=[backtest_buy_hold(ticker),
            backtest_ma(ticker,240),
            backtest_momenutm(ticker,252,0.00)
    ]

    all_results.extend(results)

    results_df=pd.DataFrame(all_results)

    print(results_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 7
#       3 for ticker in tickers:
#       4
#       5     results=[backtest_buy_hold(ticker),
#       6             backtest_ma(ticker,240),
# ----> 7             backtest_momenutm(ticker,252,0.00)
#       8     ]
#       9
#      10     all_results.extend(results)
#
# NameError: name 'backtest_momenutm' is not defined

# %%
all_results=[]

for ticker in tickers:

    results=[backtest_buy_hold(ticker),
            backtest_ma(ticker,240),
            backtest_momentum(ticker,252,0.00)
    ]

    all_results.extend(results)

    results_df=pd.DataFrame(all_results)

    print(results_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#   Ticker        Strategy  Final Return  Max Drawdown    Sharpe
# 0   ALAB      Buy & Hold      5.006932     -0.636925  1.180998
# 1   ALAB  Moving Average      3.285483     -0.497459  1.076062
# 2   ALAB        Momentum      3.510573     -0.601914  1.096353
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#   Ticker        Strategy  Final Return  Max Drawdown    Sharpe
# 0   ALAB      Buy & Hold      5.006932     -0.636925  1.180998
# 1   ALAB  Moving Average      3.285483     -0.497459  1.076062
# 2   ALAB        Momentum      3.510573     -0.601914  1.096353
# 3    HWM      Buy & Hold      8.680735     -0.201394  1.518780
# 4    HWM  Moving Average      7.897920     -0.194132  1.636836
# 5    HWM        Momentum      6.926632     -0.232037  1.534882
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#   Ticker        Strategy  Final Return  Max Drawdown    Sharpe
# 0   ALAB      Buy & Hold      5.006932     -0.636925  1.180998
# 1   ALAB  Moving Average      3.285483     -0.497459  1.076062
# 2   ALAB        Momentum      3.510573     -0.601914  1.096353
# 3    HWM      Buy & Hold      8.680735     -0.201394  1.518780
# 4    HWM  Moving Average      7.897920     -0.194132  1.636836
# 5    HWM        Momentum      6.926632     -0.232037  1.534882
# 6   ICHR      Buy & Hold      1.449267     -0.718293  0.461070
# 7   ICHR  Moving Average      2.420586     -0.445582  0.626998
# 8   ICHR        Momentum      1.306431     -0.576372  0.333564
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#    Ticker        Strategy  Final Return  Max Drawdown    Sharpe
# 0    ALAB      Buy & Hold      5.006932     -0.636925  1.180998
# 1    ALAB  Moving Average      3.285483     -0.497459  1.076062
# 2    ALAB        Momentum      3.510573     -0.601914  1.096353
# 3     HWM      Buy & Hold      8.680735     -0.201394  1.518780
# 4     HWM  Moving Average      7.897920     -0.194132  1.636836
# 5     HWM        Momentum      6.926632     -0.232037  1.534882
# 6    ICHR      Buy & Hold      1.449267     -0.718293  0.461070
# 7    ICHR  Moving Average      2.420586     -0.445582  0.626998
# 8    ICHR        Momentum      1.306431     -0.576372  0.333564
# 9    RKLB      Buy & Hold      6.986681     -0.829633  0.875081
# 10   RKLB  Moving Average      9.410505     -0.628026  1.019272
# 11   RKLB        Momentum      7.539271     -0.609931  0.944250
