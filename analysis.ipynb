# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# データ取得（Apple）
df = yf.download("AAPL", start="2020-01-01", end="2024-01-01")

# 最初の5行表示
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.400528  72.460791  71.156689  71.409793  135480400
# 2020-01-03  71.696632  72.455950  71.472454  71.629138  146322800
# 2020-01-06  72.267937  72.306506  70.568510  70.819208  118387200
# 2020-01-07  71.928047  72.533087  71.708687  72.277571  108872000
# 2020-01-08  73.085121  73.386438  71.631567  71.631567  132079200

# %%
df["Close"].plot(title="AAPL Price")
plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# データ取得（Apple）
df = yf.download("NVDA", start="2020-01-01", end="2024-01-01")

# 最初の5行表示
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price          Close      High       Low      Open     Volume
# Ticker          NVDA      NVDA      NVDA      NVDA       NVDA
# Date
# 2020-01-02  5.970754  5.970754  5.891363  5.941884  237536000
# 2020-01-03  5.875186  5.918989  5.826158  5.851046  205384000
# 2020-01-06  5.899826  5.905052  5.755727  5.781859  262636000
# 2020-01-07  5.971252  6.017045  5.883150  5.928197  314856000
# 2020-01-08  5.982450  6.023763  5.926951  5.967020  277108000

# %%
df["Close"].plot(title="NVDAPrice")
plt.show()

# %%
# リターン計算（対数リターン）
import numpy as np

df["Return"] = np.log(df["Close"] / df["Close"].shift(1))

df[["Close", "Return"]].head()
# Out:
# Price          Close    Return
# Ticker          NVDA
# Date
# 2020-01-02  5.970754       NaN
# 2020-01-03  5.875186 -0.016135
# 2020-01-06  5.899826  0.004185
# 2020-01-07  5.971252  0.012034
# 2020-01-08  5.982450  0.001874

# %%
df["Return"].plot(title="AAPL Log Returns")
plt.show()

# %%
df["Return"].hist(bins=50)
plt.title("Return Distribution")
plt.show()

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# データ取得（Apple）
df = yf.download("^N225", start="2020-01-01", end="2024-01-01")

# 最初の5行表示
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open    Volume
# Ticker             ^N225         ^N225         ^N225         ^N225     ^N225
# Date
# 2020-01-06  23204.859375  23365.359375  23148.529297  23319.759766  72800000
# 2020-01-07  23575.720703  23577.439453  23299.919922  23320.119141  64300000
# 2020-01-08  23204.759766  23303.210938  22951.179688  23217.490234  79400000
# 2020-01-09  23739.869141  23767.089844  23506.150391  23530.289062  62200000
# 2020-01-10  23850.570312  23903.289062  23761.080078  23813.279297  55900000

# %%
df["Close"].plot(title="^N225 Price")
plt.show()

# %%
# リターン計算（対数リターン）
import numpy as np

df["Return"] = np.log(df["Close"] / df["Close"].shift(1))

df[["Close", "Return"]].head()
# Out:
# Price              Close    Return
# Ticker             ^N225
# Date
# 2020-01-06  23204.859375       NaN
# 2020-01-07  23575.720703  0.015856
# 2020-01-08  23204.759766 -0.015860
# 2020-01-09  23739.869141  0.022798
# 2020-01-10  23850.570312  0.004652

# %%
df["Return"].plot(title="^N225 Log Returns")
plt.show()

# %%
df["Return"].hist(bins=50)
plt.title("Return Distribution")
plt.show()

# %%
# CSV保存
df.to_csv("AAPL_data.csv")

# %%
df.to_csv("data/AAPL_data.csv")

# %%
# CSV保存
df.to_csv("NVDA_data.csv")

# %%
df.to_csv("data/^N225_data.csv")

# %%
a=10

# %%
a
# Out:
# 10

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df=pd.read_csv("APPL_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df=pd.read_csv("APPL_data.csv")
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'APPL_data.csv'

# %%
df=pd.read_csv("AAPL_data.csv")

# %%
df.hed()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.hed()
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'hed'

# %%
df.head()
# Out:
#         Price            Close             High              Low  \
# 0      Ticker            ^N225            ^N225            ^N225
# 1        Date              NaN              NaN              NaN
# 2  2020-01-06     23204.859375     23365.359375  23148.529296875
# 3  2020-01-07  23575.720703125  23577.439453125  23299.919921875
# 4  2020-01-08  23204.759765625    23303.2109375    22951.1796875
#
#               Open    Volume    Return
# 0            ^N225     ^N225       NaN
# 1              NaN       NaN       NaN
# 2  23319.759765625  72800000       NaN
# 3  23320.119140625  64300000  0.015856
# 4  23217.490234375  79400000 -0.015860

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (1.3.0)
# Requirement already satisfied: pandas>=1.3.0 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (3.0.2)
# Requirement already satisfied: numpy>=1.16.5 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: requests>=2.31 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (2.33.1)
# Requirement already satisfied: multitasking>=0.0.7 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (4.9.6)
# Requirement already satisfied: pytz>=2022.5 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (2026.1.post1)
# Requirement already satisfied: frozendict>=2.3.4 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (4.0.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.15 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (7.34.1)
# Requirement already satisfied: websockets>=13.0 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from curl_cffi>=0.15->yfinance) (2026.4.22)
# Requirement already satisfied: rich in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from pandas>=1.3.0->yfinance) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from requests>=2.31->yfinance) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\kido_\miniconda3\envs\quant\Lib\site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)

# %%
import yfinance as yf

# %%
df=yf.download("AAPL",start="2020-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head
# Out:
# <bound method NDFrame.head of Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.400513   72.460776   71.156674   71.409778  135480400
# 2020-01-03   71.696640   72.455958   71.472462   71.629145  146322800
# 2020-01-06   72.267952   72.306521   70.568525   70.819223  118387200
# 2020-01-07   71.928070   72.533110   71.708710   72.277594  108872000
# 2020-01-08   73.085121   73.386438   71.631567   71.631567  132079200
# ...                ...         ...         ...         ...        ...
# 2026-05-04  276.829987  280.630005  274.859985  279.660004   46668400
# 2026-05-05  284.179993  284.570007  276.500000  276.929993   49311700
# 2026-05-06  287.510010  288.029999  281.070007  281.920013   58336100
# 2026-05-07  287.440002  292.130005  285.779999  289.269989   45224300
# 2026-05-08  293.320007  294.760010  290.000000  290.010010   52631200
#
# [1596 rows x 5 columns]>

# %%
df.colomn
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.colomn
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colomn'

# %%
df.columns
# Out:
# MultiIndex([( 'Close', 'AAPL'),
#             (  'High', 'AAPL'),
#             (   'Low', 'AAPL'),
#             (  'Open', 'AAPL'),
#             ('Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
df.["Close"]
# Out:
#   Cell In[15], line 1
#     df.["Close"]
#        ^
# SyntaxError: invalid syntax

# %%
df[close]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df[close]
#
# NameError: name 'close' is not defined

# %%
de["close"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 de["close"]
#
# NameError: name 'de' is not defined

# %%
df["close"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df["close"]
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\frame.py:4377, in DataFrame.__getitem__(self, key)
#    4373         is_single_key = isinstance(key, tuple) or not is_list_like(key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
# -> 4377                 return self._getitem_multilevel(key)
#    4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\frame.py:4435, in DataFrame._getitem_multilevel(self, key)
#    4433     def _getitem_multilevel(self, key):
#    4434         # self.columns is a MultiIndex
# -> 4435         loc = self.columns.get_loc(key)
#    4436         if isinstance(loc, (slice, np.ndarray)):
#    4437             new_columns = self.columns[loc]
#    4438             result_columns = maybe_droplevels(new_columns, key)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\indexes\multi.py:3523, in MultiIndex.get_loc(self, key)
#    3520     return mask
#    3522 if not isinstance(key, tuple):
# -> 3523     loc = self._get_level_indexer(key, level=0)
#    3524     return _maybe_to_slice(loc)
#    3526 keylen = len(key)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\indexes\multi.py:3885, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3882         return slice(i, j, step)
#    3884 else:
# -> 3885     idx = self._get_loc_single_level_index(level_index, key)
#    3887     if level > 0 or self._lexsort_depth == 0:
#    3888         # Desired level is not sorted
#    3889         if isinstance(idx, slice):
#    3890             # test_get_loc_partial_timestamp_multiindex
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\indexes\multi.py:3458, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    3456     return -1
#    3457 else:
# -> 3458     return level_index.get_loc(key)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'close'

# %%
df["Close"]
# Out:
# Ticker            AAPL
# Date
# 2020-01-02   72.400513
# 2020-01-03   71.696640
# 2020-01-06   72.267952
# 2020-01-07   71.928070
# 2020-01-08   73.085121
# ...                ...
# 2026-05-04  276.829987
# 2026-05-05  284.179993
# 2026-05-06  287.510010
# 2026-05-07  287.440002
# 2026-05-08  293.320007
#
# [1596 rows x 1 columns]

# %%
df["Close"].mean()
# Out:
# Ticker
# AAPL    170.198432
# dtype: float64

# %%
df["Close"].max
# Out:
# <bound method DataFrame.max of Ticker            AAPL
# Date
# 2020-01-02   72.400513
# 2020-01-03   71.696640
# 2020-01-06   72.267952
# 2020-01-07   71.928070
# 2020-01-08   73.085121
# ...                ...
# 2026-05-04  276.829987
# 2026-05-05  284.179993
# 2026-05-06  287.510010
# 2026-05-07  287.440002
# 2026-05-08  293.320007
#
# [1596 rows x 1 columns]>

# %%
df["Close"].max()
# Out:
# Ticker
# AAPL    293.320007
# dtype: float64

# %%
df["Close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["MA50"]=df["Close"].rolling(50).mean()

# %%
df.tail()
# Out:
# Price            Close        High         Low        Open    Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-05-04  276.829987  280.630005  274.859985  279.660004  46668400
# 2026-05-05  284.179993  284.570007  276.500000  276.929993  49311700
# 2026-05-06  287.510010  288.029999  281.070007  281.920013  58336100
# 2026-05-07  287.440002  292.130005  285.779999  289.269989  45224300
# 2026-05-08  293.320007  294.760010  290.000000  290.010010  52631200
#
# Price             MA50
# Ticker
# Date
# 2026-05-04  261.463600
# 2026-05-05  261.823600
# 2026-05-06  262.131000
# 2026-05-07  262.395200
# 2026-05-08  262.802599

# %%
df[["Close","MA50]].plot(figsize=(12,5))
# Out:
#   Cell In[26], line 1
#     df[["Close","MA50]].plot(figsize=(12,5))
#                 ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df[["Close","MA50"]].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df["Signal"]=df["Close"]>df["MA50"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df["Signal"]=df["Close"]>df["MA50"]
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\arraylike.py:58, in OpsMixin.__gt__(self, other)
#      56 @unpack_zerodim_and_defer("__gt__")
#      57 def __gt__(self, other):
# ---> 58     return self._cmp_method(other, operator.gt)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\frame.py:9123, in DataFrame._cmp_method(self, other, op)
#    9120     def _cmp_method(self, other, op):
#    9121         axis: Literal[1] = 1  # only relevant for Series other case
#    9122
# -> 9123         self, other = self._align_for_op(other, axis, flex=False, level=None)
#    9124
#    9125         # See GH#4537 for discussion of scalar op behavior
#    9126         new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\frame.py:9446, in DataFrame._align_for_op(self, other, axis, flex, level)
#    9442             # axis=1 is default for DataFrame-with-Series op
#    9443             axis = axis if axis is not None else 1
#    9444             if not flex:
#    9445                 if not left.axes[axis].equals(right.index):
# -> 9446                     raise ValueError(
#    9447                         "Operands are not aligned. Do "
#    9448                         "`left, right = left.align(right, axis=1)` "
#    9449                         "before operating."
#
# ValueError: Operands are not aligned. Do `left, right = left.align(right, axis=1)` before operating.

# %%
close=df["Close"]["AAPL"]

# %%
ma50=close.rolling(50).mean()

# %%
signal=close>ma50

# %%
signal.tail()
# Out:
# Date
# 2026-05-04    True
# 2026-05-05    True
# 2026-05-06    True
# 2026-05-07    True
# 2026-05-08    True
# Name: AAPL, dtype: bool

# %%
signal.astype(int)
# Out:
# Date
# 2020-01-02    0
# 2020-01-03    0
# 2020-01-06    0
# 2020-01-07    0
# 2020-01-08    0
#              ..
# 2026-05-04    1
# 2026-05-05    1
# 2026-05-06    1
# 2026-05-07    1
# 2026-05-08    1
# Name: AAPL, Length: 1596, dtype: int64

# %%
signal.astype(int).tail()
# Out:
# Date
# 2026-05-04    1
# 2026-05-05    1
# 2026-05-06    1
# 2026-05-07    1
# 2026-05-08    1
# Name: AAPL, dtype: int64

# %% [raw]
# returns=close.pct_changer()

# %%
returns.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 returns.tail()
#
# NameError: name 'returns' is not defined

# %%
returns.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 returns.tail()
#
# NameError: name 'returns' is not defined

# %%
returns=close.pct_change()

# %%
returns.tail()
# Out:
# Date
# 2026-05-04   -0.011816
# 2026-05-05    0.026551
# 2026-05-06    0.011718
# 2026-05-07   -0.000243
# 2026-05-08    0.020456
# Name: AAPL, dtype: float64

# %%
strategy_returns=signal.shift(1).astype(int)*returns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 strategy_returns=signal.shift(1).astype(int)*returns
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\internals\managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\internals\managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\internals\blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\dtypes\astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\dtypes\astype.py:185, in astype_array(values, dtype, copy)
#     182     values = values.astype(dtype, copy=copy)
#     184 else:
# --> 185     values = _astype_nansafe(values, dtype, copy=copy)
#     187 # in pandas we don't store numpy str dtypes, so convert to object
#     188 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or object in (arr.dtype, dtype):
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: cannot convert float NaN to integer

# %%
strategy_returns=signal.shift(1).fillna(False).astype(int)*returns

# %%
cumulative_returns=(1+strategy_returns).comprod()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 cumulative_returns=(1+strategy_returns).comprod()
#
# File ~\miniconda3\envs\quant\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'comprod'

# %%
cumulative_returns=(1+strategy_returns).cumprod()

# %%
cumulative_returns.tail()
# Out:
# Date
# 2026-05-04    2.413685
# 2026-05-05    2.477770
# 2026-05-06    2.506804
# 2026-05-07    2.506194
# 2026-05-08    2.557462
# Name: AAPL, dtype: float64

# %%
cumulative_returns.plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>
